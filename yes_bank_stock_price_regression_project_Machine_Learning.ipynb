# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikita7414/yes-bank-stock-price-regression-project-ML/blob/main/yes_bank_stock_price_regression_project_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# # <center>📈<font color=#D2691E>**Yes Bank Stock Closing Price Prediction**</font>📉</center>
# ---

# %% [markdown]
# ![Yes_Bank_logo.png](data:image/png;base64,...)

# %% [markdown]
# ##### **Project Type**    - EDA(Supervised - Regression)
# ##### **Contribution**    - Team
# ##### **Team Member 1 -**  Nikita Maske
# ##### **Team Member 2 -**  Pratik Mapari

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# # <center>**Let's First make Understanding of the [Stock Market](https://www.investopedia.com/articles/investing/082614/how-stock-market-works.asp)**</center>
#
#
# > **Stock Market :** The term stock market refers to several exchanges in which shares of publicly held companies are bought and sold. Such financial activities are conducted through formal exchanges and via over-the-counter (OTC) marketplaces that operate under a defined set of regulations.
#
# * Both ***stock market*** and ***stock exchange*** are often used interchangeably. Traders in the stock market buy or sell shares on one or more of the stock exchanges that are part of the overall stock market.
# ## **<u>KEY TAKEAWAYS</u>**
# * Stock markets are venues where buyers and sellers meet to exchange equity shares of public corporations.
# * Stock markets are components of a free-market economy because they enable democratized access to investor trading and exchange of capital.
# * Stock markets create efficient price discovery and efficient dealing.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Nikita7414/EDA_Project

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Yes Bank is a well-known Indian bank headquartered in Mumbai, India and was founded by Rana Kapoor and Ashok Kapoor in 2004. It offers wide range of differentiated products for corporate and retail customers through retail banking and asset management services.Yes Bank is a publicly traded company listed on the stock market and is therefore subject to the ups and downs of the stock market cycle.The stock market is driven by speculation. The investors decide on buying or selling shares of a company based on its performance and its reputation. Public opinion has a huge impact on stock market prices.Which is why when the news of fraud case involving Rana Kapoor broke in 2018, stock price of Yes bank went down significantly.
#
# Here we are presented with the stock market price data of Yes bank and our job is to try and predict stock’s closing price of the month. This data contains the date, lowest, highest and closing price details.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Importing Required Library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from numpy import math

from sklearn.preprocessing import MinMaxScaler
from scipy.stats import zscore
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.linear_model import LinearRegression ,Ridge,Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor
from statsmodels.stats.outliers_influence import variance_inflation_factor

from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn import metrics
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Mount Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load Dataset
df1=pd.read_csv('/content/drive/MyDrive/data_YesBank_StockPrices.csv')
df1
# Out:
#        Date   Open   High    Low  Close
# 0    Jul-05  13.00  14.00  11.25  12.46
# 1    Aug-05  12.58  14.88  12.55  13.42
# 2    Sep-05  13.48  14.87  12.27  13.30
# 3    Oct-05  13.20  14.47  12.40  12.99
# 4    Nov-05  13.35  13.88  12.88  13.41
# ..      ...    ...    ...    ...    ...
# 180  Jul-20  25.60  28.30  11.10  11.95
# 181  Aug-20  12.00  17.16  11.85  14.37
# 182  Sep-20  14.30  15.34  12.75  13.15
# 183  Oct-20  13.30  14.01  12.11  12.42
# 184  Nov-20  12.41  14.90  12.21  14.67
#
# [185 rows x 5 columns]

# %%
#creating copy of dataset
df=df1.copy()
df
# Out:
#        Date   Open   High    Low  Close
# 0    Jul-05  13.00  14.00  11.25  12.46
# 1    Aug-05  12.58  14.88  12.55  13.42
# 2    Sep-05  13.48  14.87  12.27  13.30
# 3    Oct-05  13.20  14.47  12.40  12.99
# 4    Nov-05  13.35  13.88  12.88  13.41
# ..      ...    ...    ...    ...    ...
# 180  Jul-20  25.60  28.30  11.10  11.95
# 181  Aug-20  12.00  17.16  11.85  14.37
# 182  Sep-20  14.30  15.34  12.75  13.15
# 183  Oct-20  13.30  14.01  12.11  12.42
# 184  Nov-20  12.41  14.90  12.21  14.67
#
# [185 rows x 5 columns]

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#      Date   Open   High    Low  Close
# 0  Jul-05  13.00  14.00  11.25  12.46
# 1  Aug-05  12.58  14.88  12.55  13.42
# 2  Sep-05  13.48  14.87  12.27  13.30
# 3  Oct-05  13.20  14.47  12.40  12.99
# 4  Nov-05  13.35  13.88  12.88  13.41

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (185, 5)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    185 non-null    object
#  1   Open    185 non-null    float64
#  2   High    185 non-null    float64
#  3   Low     185 non-null    float64
#  4   Close   185 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 7.4+ KB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# Date     0
# Open     0
# High     0
# Low      0
# Close    0
# dtype: int64

# %%
# Visualizing the missing values
#cheacking null values by plotting Heatmap
plt.figure(figsize=(5,5))
sns.heatmap(df.isnull(),cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The given dataset is about yes bank stock price prediction.This dataset contains 185 rows and 5 columns.We have to perform exploratory data analysis with python to get insight from the data. In this dataset there are no missing values and no duplicate values.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close'], dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#              Open        High         Low       Close
# count  185.000000  185.000000  185.000000  185.000000
# mean   105.541405  116.104324   94.947838  105.204703
# std     98.879850  106.333497   91.219415   98.583153
# min     10.000000   11.240000    5.550000    9.980000
# 25%     33.800000   36.140000   28.510000   33.450000
# 50%     62.980000   72.550000   58.000000   62.540000
# 75%    153.000000  169.190000  138.350000  153.300000
# max    369.950000  404.000000  345.500000  367.900000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **Since, we've seen the YES BANK Stock price dataset which has the monthly stock prices. It contains the following features:**
#
# **Open** - The opening price is the price at which a security first trades upon the opening of an exchange on a trading day i.e. buyers and sellers meet to make deals with the highest bidder, the opening price may not have to be the same as the last day's closing price.
#
# **High** - The high is the highest price at which a stock traded during a period.
#
# **Low** -The low is the highest price at which a stock traded during a period.
#
# **Close** -The closing price is a stock's trading price at the end of a trading day. This makes it the most recent price of a stock until the next trading session. The closing price is calculated as the weighted average price of the last 30 minutes, i.e. from 3:00 PM to 3:30 PM in case of equity.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df['Open'].unique()
# Out:
# array([ 13.  ,  12.58,  13.48,  13.2 ,  13.35,  13.49,  13.68,  15.5 ,
#         16.2 ,  20.56,  19.8 ,  18.2 ,  16.  ,  15.9 ,  18.  ,  18.78,
#         22.8 ,  25.4 ,  27.4 ,  30.2 ,  29.3 ,  27.  ,  30.66,  33.89,
#         35.98,  37.5 ,  37.4 ,  41.8 ,  44.4 ,  46.4 ,  49.99,  50.88,
#         48.9 ,  33.9 ,  34.3 ,  31.22,  22.85,  25.  ,  26.68,  24.6 ,
#         14.79,  12.4 ,  15.28,  12.19,  10.  ,  10.04,  15.94,  25.6 ,
#         29.7 ,  31.98,  33.8 ,  41.2 ,  46.58,  50.98,  53.6 ,  49.  ,
#         47.8 ,  50.67,  56.94,  56.7 ,  53.55,  59.4 ,  62.8 ,  70.9 ,
#         72.2 ,  61.8 ,  62.98,  53.  ,  51.84,  62.  ,  61.26,  60.4 ,
#         63.  ,  62.9 ,  56.  ,  53.8 ,  62.2 ,  57.  ,  47.92,  65.9 ,
#         69.  ,  73.62,  70.4 ,  65.45,  68.15,  73.  ,  66.2 ,  76.4 ,
#         82.54,  89.2 ,  93.2 , 104.41,  94.  ,  85.7 , 100.99,  99.  ,
#         92.4 ,  66.  ,  49.2 ,  58.  ,  74.  ,  74.4 ,  74.74,  61.54,
# ...

# %%
df['High'].unique()
# Out:
# array([ 14.  ,  14.88,  14.87,  14.47,  13.88,  14.44,  17.16,  16.97,
#         20.95,  20.8 ,  21.8 ,  18.4 ,  17.2 ,  18.6 ,  18.88,  24.2 ,
#         28.47,  29.66,  34.16,  32.6 ,  31.58,  31.99,  36.14,  36.38,
#         41.04,  39.  ,  41.75,  47.3 ,  50.98,  54.  ,  55.56,  53.97,
#         48.9 ,  35.8 ,  36.88,  32.22,  30.5 ,  28.98,  29.8 ,  25.  ,
#         17.8 ,  16.56,  18.34,  12.5 ,  11.24,  17.51,  28.84,  31.08,
#         33.16,  35.18,  41.3 ,  52.34,  54.98,  55.67,  57.58,  51.48,
#         52.06,  59.48,  58.08,  59.9 ,  60.94,  68.88,  71.74,  76.  ,
#         77.6 ,  68.36,  63.54,  57.69,  65.2 ,  68.26,  61.68,  63.39,
#         68.  ,  63.96,  60.08,  64.8 ,  63.7 ,  59.8 ,  66.5 ,  74.8 ,
#         77.88,  76.1 ,  70.59,  70.6 ,  73.19,  74.78,  77.69,  84.2 ,
#         89.6 ,  95.  , 107.  , 107.8 , 100.15, 101.8 , 109.43, 102.94,
#        100.4 ,  67.81,  78.94,  76.44,  77.27,  83.  ,  76.35,  62.7 ,
# ...

# %%
df['Low'].unique()
# Out:
# array([ 11.25,  12.55,  12.27,  12.4 ,  12.88,  13.  ,  13.58,  15.4 ,
#         16.02,  18.02,  15.8 ,  13.4 ,  13.82,  15.7 ,  16.8 ,  18.5 ,
#         21.4 ,  24.4 ,  27.  ,  26.8 ,  23.31,  26.2 ,  29.11,  30.4 ,
#         35.02,  30.2 ,  35.3 ,  33.6 ,  40.02,  45.  ,  30.24,  44.4 ,
#         24.11,  28.51,  30.03,  22.62,  20.4 ,  24.62,  21.7 ,  11.01,
#         11.13,  11.48,   9.9 ,   8.16,   9.94,  14.76,  23.  ,  24.83,
#         29.  ,  32.  ,  36.8 ,  42.84,  48.6 ,  46.42,  44.6 ,  47.3 ,
#         48.8 ,  50.66,  52.6 ,  53.02,  59.01,  62.51,  68.21,  58.  ,
#         55.44,  49.39,  46.71,  50.8 ,  60.5 ,  54.5 ,  54.8 ,  61.36,
#         50.51,  51.2 ,  48.1 ,  52.04,  47.4 ,  46.11,  63.6 ,  66.2 ,
#         69.11,  58.85,  62.14,  67.57,  65.27,  64.46,  75.6 ,  82.22,
#         88.01,  93.2 ,  93.4 ,  83.42,  83.43,  97.2 ,  87.15,  57.71,
#         43.22,  44.8 ,  56.08,  64.65,  71.63,  60.8 ,  58.42,  60.34,
# ...

# %%
df['Close'].unique()
# Out:
# array([ 12.46,  13.42,  13.3 ,  12.99,  13.41,  13.71,  15.33,  16.12,
#         20.08,  19.49,  18.03,  15.62,  16.16,  17.84,  18.46,  22.78,
#         25.32,  26.97,  30.16,  28.63,  28.14,  30.31,  33.51,  35.98,
#         37.93,  36.99,  41.36,  43.48,  46.18,  49.81,  50.54,  49.42,
#         33.75,  34.06,  31.13,  22.85,  25.45,  26.83,  24.13,  13.58,
#         12.26,  15.03,  12.24,  10.26,   9.98,  15.45,  25.12,  29.68,
#         31.93,  33.45,  40.99,  47.31,  50.57,  53.41,  49.84,  47.32,
#         50.97,  57.1 ,  57.57,  53.83,  58.99,  62.22,  70.3 ,  71.86,
#         61.21,  62.54,  52.59,  51.29,  61.98,  61.02,  60.07,  62.38,
#         62.13,  55.61,  54.5 ,  62.9 ,  54.49,  47.72,  65.99,  69.14,
#         73.46,  70.07,  66.02,  67.83,  72.85,  65.97,  76.44,  82.29,
#         88.48,  92.84, 104.41,  94.5 ,  85.71, 100.28,  97.49,  92.2 ,
#         64.76,  48.65,  57.5 ,  73.76,  73.74,  74.02,  61.59,  60.95,
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# >* Data wrangling is the process of converting data from the initial format to a format that may be better for analysis.*
#
#
# ## Objectives:
# *   Handle missing values
# *   Correct data format
# *   Standardize and normalize data

# %% [markdown]
# # Missing value and duplicate
#
# Since we alredy checked that there is no missing and duplictes value in the dataset, Hence we will check further dataset

# %% [markdown]
# ### Data Wrangling Code

# %%
#checking the data types
df.dtypes
# Out:
# Date      object
# Open     float64
# High     float64
# Low      float64
# Close    float64
# dtype: object

# %% [markdown]
# The Date in the given dataset is in the format of Month-YY. We need to convert it in proper date format of YYYY-MM-DD.
# Since, Date column has dtype as object we've to convert it into datetime format

# %%
# converting 'Date' into datetime - YYYY-MM-DD
# required the changing data type of date
from datetime import datetime
df['Date'] = pd.to_datetime(df['Date'].apply(lambda x: datetime.strptime(x,'%b-%y')))

# %% [markdown]
# After changing the data type of required column,now all columns are in the correct datatype

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# In the given dataset there is no missing values, no duplicates values only there is date column which is not in correct format so,
# we changed the data type of date column.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1
# ##Heatmap
#
# Checking for the missing value

# %%
# Visualizing the missing values
#cheacking null values by plotting Heatmap
plt.figure(figsize=(5,3))
sns.heatmap(df.isnull(),cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To check missing values in the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the range and visualization of color it showing that there is no missing values.

# %% [markdown]
# #### Chart - 2
# #Boxplot
# Checking for the Outlier

# %%
# Chart - 2 visualization code
sns.set_theme(style="white")
plt.figure(figsize=(10,5))

sns.boxplot(data=df,palette="Set2")
# Out:
# <Axes: >

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It is very easy to analyse and showing the outliers whether present on upper tail or lower tail.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# I found that all four columns containing outliers which are present on uppertail.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This outliers impact negatively on business, so we have to handle this outliers using methods like z_score, IQR method, Transformation and so on.
# after doing this data will be positively impact on business and increase the accuracy of data.

# %% [markdown]
# #### Chart - 3
# #Lineplot

# %%
# Chart - 2 visualization code
sns.set_theme(style="darkgrid")
plt.figure(figsize=(10,5))

sns.lineplot(x="Date", y="Close",data=df,color='g')
plt.xlabel('Year')
plt.title('Yes Bank closing price')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Line charts are a fundamental chart type generally used to show change in values across time. It represents the change in a quantity with respect to another quantity. so, in this data there is 'Date' column which contain the year that is why we took line chart to show how closing price changes across year.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Now, We can easily see in above plot the trend is increasing from 2009 to 2018 but after that the trend decreases. This is because of the fraud case of involving Rana Kapoor.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# yes,definitely it is useful for business point of view.

# %% [markdown]
# #### Chart - 4
# #Distplot

# %%
# Chart - 3 visualization code

plt.figure(figsize = (17,4))

plt.subplot(1, 3, 1)
sns.distplot(df['Open'], color = 'Blue')
plt.title('Distribution', fontsize=18)
plt.xlabel('Open', fontsize= 16)
plt.ylabel('Density', fontsize=14)

plt.subplot(1, 3, 2)
sns.distplot(df['High'], color = 'Darkorange')
plt.title('Distribution', fontsize=18)
plt.xlabel('High', fontsize= 16)

plt.subplot(1, 3, 3)
sns.distplot(df['Low'], color = 'Brown')
plt.title('Distribution', fontsize=18)
plt.xlabel('Low', fontsize= 16)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Because, it depicts the variation in the data distribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Plotting distribution of Open , High and Low numerical Features. It's looking like rightly skewed for all features.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# applying log transformation to make it normal distribution. Logarithm naturally reduces the dynamic range of a variable so the differences are preserved while the scale is not that dramatically skewed.

# %% [markdown]
# ####Chart - 5
# #Distplot

# %%
plt.figure(figsize = (4,6))
sns.distplot(np.log(df['Open']), color = 'Green')
plt.title('Distribution', fontsize=18)
plt.xlabel('Open', fontsize= 16)
plt.ylabel('Density', fontsize=14)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This is the best plot to check data is normally distributed or not.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From plot it is clearly seen that data is normally distributed.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It will increase the accuracy of model.

# %% [markdown]
# #chart-6

# %%
plt.figure(figsize=(4,5))
sns.distplot(np.log(df['High']), color = 'Darkorange')
plt.title('Distribution', fontsize=18)
plt.xlabel('High', fontsize= 16)
# Out:
# Text(0.5, 0, 'High')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This is the best plot to check data is normally distributed or not.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From plot it is clearly seen that data is normally distributed.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It will increase the accuracy of model.

# %% [markdown]
# #chart-7

# %%
plt.figure(figsize=(4,5))
sns.distplot(np.log(df['Low']), color = 'Red')
plt.title('Distribution', fontsize=18)
plt.xlabel('Low', fontsize= 16)
# Out:
# Text(0.5, 0, 'Low')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This is the best plot to check data is normally distributed or not.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From plot it is clearly seen that data is normally distributed.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It will increase the accuracy of model.

# %% [markdown]
# #### Chart - 8
# #Scatter plot

# %%
# Chart - 8 visualization code
plt.figure(figsize = (13,4))

plt.subplot(1, 3, 1)
plt.scatter(df['Close'], df['Open'], alpha=0.6,color="red")
plt.title('Scatter Plot Of Open Or Close ')
plt.xlabel('Open')
plt.ylabel('Class')
sns.regplot(x ='Open', y = 'Close', data= df)

plt.subplot(1, 3, 2)
plt.scatter(df['Close'], df['High'],color="green", alpha=0.6)
plt.title('Scatter Plot Of High Or Close ')
plt.xlabel('High')
plt.ylabel('Class')
sns.regplot(x ='High', y = 'Close', data= df)

plt.subplot(1, 3, 3)
plt.scatter(df['Close'], df['Low'],color="yellow", alpha=0.6)
plt.title('Scatter Plot Of Low Or Close ')
plt.xlabel('Low')
plt.ylabel('Class')
sns.regplot(x ='Low', y = 'Close', data= df)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find out the realation between the Dependent Variable and independent Variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# we get scatter plot with Best Fit line.We can see that all of our independent variables are highly correlated to the dependent variable.
#
# And the relationship between dependent and independent variables is linear in nature.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# yes, it will help in cheacking the  linearity of model.

# %% [markdown]
# #### Chart - 9
# #Heatmap

# %%
# Chart - 9 visualization code
# Correaltion of heatmap

plt.figure(figsize=(10,6))
sns.heatmap(df[['High','Low','Close']].corr(), annot= True, cmap= 'coolwarm')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This is used to show VIF matrix.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It showing correlation between the features in our data set

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It can effect our model efficiency.

# %% [markdown]
# # Chart - 10

# %%
# Check for skewness in the dataset
numeric_features = df.describe().columns
for col in numeric_features[0:4]:
    fig = plt.figure(figsize=(9, 6))
    ax = fig.gca()
    feature = df[col]
    feature.hist(bins=50, ax = ax)
    ax.axvline(feature.mean(), color='magenta', linestyle='dashed', linewidth=2)
    ax.axvline(feature.median(), color='cyan', linestyle='dashed', linewidth=2)
    ax.set_title(col)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To show the visual representation of mean and median of given dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The median provides a helpful measure of the centre of a dataset. By comparing the median to the mean, we can get an idea of the distribution of a dataset. When the mean and the median are the same, the dataset is more or less evenly distributed from the lowest to highest values.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
vif_list=[]
a=df.drop(['Date','Close'],axis=1)


for i in range(a.shape[1]):
  vif=variance_inflation_factor(a.to_numpy(),i)
  vif_list.append(vif)
vif_series=pd.DataFrame(vif_list,index=a.columns)
vif_series
vif_series.plot(kind="barh")
# Out:
# <Axes: >

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We are checking multicolinearity between the feature

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There is huge multicolinearity between the feature among that open and higher
# multicolinearity

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Due to this multicolinearity it will lead to falls in accuracy of model.

# %% [markdown]
# ## Chart - 12
# # Correlation Heatmap

# %%
# Correlation Heatmap visualization code
sns.heatmap(df.corr(),annot=True,cmap='magma')
# Out:
# <Axes: >

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To show the relation between each feature with the others this is the best plot.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# All variables are showing the highest correlation among them.

# %% [markdown]
# #### Chart - 13
# # - Pair Plot

# %%
sns.pairplot(df)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To visualise the relationship between each pair of variables using pair plots.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# All variables having strong correlation among them.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 1. Handling Missing Values

# %%
# Handling Missing Values & Missing Value Imputation
df.isna().sum() #there is no missing values
# Out:
# Date     0
# Open     0
# High     0
# Low      0
# Close    0
# dtype: int64

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %% [markdown]
# There is no need to use any missing value imputation techniques.

# %% [markdown]
# ### 2. Handling Outliers

# %%
# Handling Outliers & Outlier treatments
sns.set_theme(style="whitegrid")
plt.figure(figsize=(10,5))

sns.boxplot(data=df,palette="Set2")
# Out:
# <Axes: >

# %%
plt.figure(figsize = (17,4))

plt.subplot(1, 3, 1)
sns.distplot(df['Open'], color = 'Blue')
plt.title('Distribution', fontsize=18)
plt.xlabel('Open', fontsize= 16)
plt.ylabel('Density', fontsize=14)

plt.subplot(1, 3, 2)
sns.distplot(df['High'], color = 'Darkorange')
plt.title('Distribution', fontsize=18)
plt.xlabel('High', fontsize= 16)

plt.subplot(1, 3, 3)
sns.distplot(df['Low'], color = 'Brown')
plt.title('Distribution', fontsize=18)
plt.xlabel('Low', fontsize= 16)

plt.show()

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# applying log transformation to make it normal distribution.
# The log transformation is arguably, the most popular among the different types of transformations used to transform skewed data to approximately to normality. If the original data follows a log-normal distribution or approximately so, then the log-transformed data follows a normal or near to the normal distribution.

# %%
plt.figure(figsize = (17,4))

plt.subplot(1, 3, 1)
sns.distplot(np.log(df['Open']), color = 'Green')
plt.title('Distribution', fontsize=18)
plt.xlabel('Open', fontsize= 16)
plt.ylabel('Density', fontsize=14)

plt.subplot(1, 3, 2)
sns.distplot(np.log(df['High']), color = 'Darkorange')
plt.title('Distribution', fontsize=18)
plt.xlabel('High', fontsize= 16)

plt.subplot(1, 3, 3)
sns.distplot(np.log(df['Low']), color = 'Red')
plt.title('Distribution', fontsize=18)
plt.xlabel('Low', fontsize= 16)

plt.show()

# %% [markdown]
# Now, It looks like Normally Distributed of Open, High and Low.

# %% [markdown]
# ### 4. Feature Manipulation & Selection

# %%
# Select your features wisely to avoid overfitting
# Correlation Heatmap visualization code
sns.heatmap(df.corr(),annot=True,cmap='magma')
# Out:
# <Axes: >

# %%
# varience inflation factor
vif_list=[]
a=df.drop(['Date','Close'],axis=1)


for i in range(a.shape[1]):
  vif=variance_inflation_factor(a.to_numpy(),i)
  vif_list.append(vif)
vif_series=pd.DataFrame(vif_list,index=a.columns)
vif_series
vif_series.plot(kind="barh")
# Out:
# <Axes: >

# %% [markdown]
# ##### Which all features you found important and why?

# %% [markdown]
# So, Open, High and Low these features are found important.

# %% [markdown]
# ### 5. Data Transformation

# %%
# Data  Transformation
x=df.drop(['Date','Close'],axis=1)
x=np.log(x)
y=df['Close']
x
# Out:
#          Open      High       Low
# 0    2.564949  2.639057  2.420368
# 1    2.532108  2.700018  2.529721
# 2    2.601207  2.699346  2.507157
# 3    2.580217  2.672078  2.517696
# 4    2.591516  2.630449  2.555676
# ..        ...       ...       ...
# 180  3.242592  3.342862  2.406945
# 181  2.484907  2.842581  2.472328
# 182  2.660260  2.730464  2.545531
# 183  2.587764  2.639771  2.494032
# 184  2.518503  2.701361  2.502255
#
# [185 rows x 3 columns]

# %% [markdown]
# #### Do you think that your data needs to be transformed? If yes, which transformation have you used. Explain Why?

# %% [markdown]
# - Yes definetely,As we have seen data is not normally distributed  it is righly skewed and we require the data that should be  normally distributed
# - The log transformation is, arguably, the most popular among the different types of transformations used to transform skewed data to approximately conform to normality. If the original data follows a log-normal distribution or approximately so, then the log-transformed data follows a normal or near normal distribution.

# %% [markdown]
# ### 6. Data Scaling

# %%
#Standardization
std_scalar=StandardScaler()
array=std_scalar.fit_transform(x_train)
x_train_std_df=pd.DataFrame(array, columns=x_train.columns)
knn_reg=KNeighborsRegressor(n_neighbors=7,p=1)
knn_reg.fit(x_train_std_df,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=7, p=1)

# %%
#Normalization
normal_scalar=MinMaxScaler()
array=normal_scalar.fit_transform(x_train)
x_train_normal_df=pd.DataFrame(array,columns=x_train.columns)
knn_reg=KNeighborsRegressor(n_neighbors=7,p=1)
knn_reg.fit(x_train_normal_df,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=7, p=1)

# %% [markdown]
# ##### Which method have you used to scale you data and why?

# %% [markdown]
# We used two methods for scalling namely
# - Normalization
# - Standerdization
#
#
# Because we slighly belive that it can gives good result
# and also it is mandatory for the distance based algorithm

# %%
#Creating an list for final aacuracy dataframe
model_details = ['LinearRegression','Ridge','Lasso','Ridgr_hyper','Lasso_hyper','DecisionTree','DecisionTree_Hyper_pre','DecisionTree_Hyper_post',
                 'RandomForest','KNN',"KNN_Normalization",'KNN_standerdization','AdaBoost',"xgboost"]
testing_accuracy_list = []
training_accuracy_list = []

# %% [markdown]
# ### 8. Data Splitting

# %% [markdown]
# Train Test Split
# Splitting Data
#
# X = Independent Variable
#
# y = Dependent Variable

# %%
# Split your data to train and test. Choose Splitting ratio wisely.
x=df.drop(['Date','Close'],axis=1)
x=np.log(x)
y=df['Close']
x
# Out:
#          Open      High       Low
# 0    2.564949  2.639057  2.420368
# 1    2.532108  2.700018  2.529721
# 2    2.601207  2.699346  2.507157
# 3    2.580217  2.672078  2.517696
# 4    2.591516  2.630449  2.555676
# ..        ...       ...       ...
# 180  3.242592  3.342862  2.406945
# 181  2.484907  2.842581  2.472328
# 182  2.660260  2.730464  2.545531
# 183  2.587764  2.639771  2.494032
# 184  2.518503  2.701361  2.502255
#
# [185 rows x 3 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=12)

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
# The split ratio is 75:25. That is 75% of the dataset goes into the training set and 25% of the dataset goes into the testing set.

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (138, 3)
# (47, 3)
# (138,)
# (47,)

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1

# %%
# ML Model - 1 Implementation
model_lin_regression=LinearRegression()

# Fit the Algorithm
model_lin_regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# Predict on the model
y_train_pred=model_lin_regression.predict(x_train)

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.
# Linear-regression models are relatively simple and provide an easy-to-interpret mathematical formula that can generate predictions. Linear regression can be applied to various areas in business and academic study.
#
# You’ll find that linear regression is used in everything from biological, behavioral, environmental and social sciences to business. Linear-regression models have become a proven way to scientifically and reliably predict the future. Because linear regression is a long-established statistical procedure, the properties of linear-regression models are well understood and can be trained very quickly.
# The linear regression model returns an equation that determines the relationship between the independent variables and the dependent variable.

# %%
# Visualizing evaluation Metric Score chart
#Training

mse=mean_squared_error(y_train_pred,y_train)
rmse=np.sqrt(mse)
mae=mean_absolute_error(y_train_pred,y_train)

r2=r2_score(y_train_pred,y_train)

print('mean_squared_error:',mse)
print("*"*60)

print('rmse:',rmse)
print("*"*60)

print('mean_absolute_error:',mae)
print("*"*60)

print('r2_score:',r2)
training_accuracy_list.append(r2)
# Out:
# mean_squared_error: 1615.8309638162693
# ************************************************************
# rmse: 40.197399963384065
# ************************************************************
# mean_absolute_error: 33.722225746838255
# ************************************************************
# r2_score: 0.8132687628951601

# %%
# Visualizing evaluation Metric Score chart
#Testing
y_test_pred=model_lin_regression.predict(x_test)
mse=mean_squared_error(y_test_pred,y_test)
rmse=np.sqrt(mse)
mae=mean_absolute_error(y_test_pred,y_test)

r2=r2_score(y_test_pred,y_test)

print('mean_squared_error:',mse)
print("*"*60)

print('rmse:',rmse)
print("*"*60)

print('mean_absolute_error:',mae)
print("*"*60)

print('r2_score:',r2)
testing_accuracy_list.append(r2)
# Out:
# mean_squared_error: 2043.0568623633703
# ************************************************************
# rmse: 45.20018653018337
# ************************************************************
# mean_absolute_error: 40.668222977235565
# ************************************************************
# r2_score: 0.7804175656322877

# %%
plt.figure(figsize=(8,5))
sns.set_theme(style='darkgrid')
sns.scatterplot(x=y_test,y=y_test_pred,color='red')
plt.xlabel('Actual  test value')
plt.ylabel('Predicted test value')
# Out:
# Text(0, 0.5, 'Predicted test value')

# %% [markdown]
# #📍Implementing Ridge Regression
# Ridge Regression:
# As mentioned before, ridge regression performs ‘L2 regularization‘, i.e. it adds a factor of sum of squares of coefficients in the optimization objective. Thus, ridge regression optimizes the following:
#
# Objective = RSS + α * (sum of square of coefficients)
# Here, α (alpha) is the parameter which balances the amount of emphasis given to minimizing RSS vs minimizing sum of square of coefficients. α can take various values:
#
# α = 0:
# The objective becomes same as simple linear regression.
# We’ll get the same coefficients as simple linear regression.
# α = ∞:
# The coefficients will be zero. Why? Because of infinite weightage on square of coefficients, anything less than zero will make the objective infinite.
# 0 < α < ∞:
# The magnitude of α will decide the weightage given to different parts of objective.
# The coefficients will be somewhere between 0 and ones for simple linear regression.
# I hope this gives some sense on how α would impact the magnitude of coefficients. One thing is for sure that any non-zero value would give values less than that of simple linear regression. By how much? We’ll find out soon. Leaving the mathematical details for later, lets see ridge regression in action on the same problem as above.

# %%
# fit data into ridge regression
ridg_reg=Ridge(alpha=0.001)
ridg_reg.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.001)

# %%
# Accuracy of Ridge regression model
#Training
y_train_pred=ridg_reg.predict(x_train)
mse=mean_squared_error(y_train_pred,y_train)
rmse=np.sqrt(mse)
mae=mean_absolute_error(y_train_pred,y_train)

r2=r2_score(y_train_pred,y_train)

print('mean_squared_error:',mse)
print("*"*60)

print('rmse:',rmse)
print("*"*60)

print('mean_absolute_error:',mae)
print("*"*60)

print('r2_score:',r2)
training_accuracy_list.append(r2)
# Out:
# mean_squared_error: 1615.831232845248
# ************************************************************
# rmse: 40.19740330973194
# ************************************************************
# mean_absolute_error: 33.72345783229927
# ************************************************************
# r2_score: 0.8132604840559561

# %%
# Accuracy of Ridge regression model
#Testing
y_test_pred=ridg_reg.predict(x_test)
mse=mean_squared_error(y_test_pred,y_test)
rmse=np.sqrt(mse)
mae=mean_absolute_error(y_test_pred,y_test)

r2=r2_score(y_test_pred,y_test)

print('mean_squared_error:',mse)
print("*"*60)

print('rmse:',rmse)
print("*"*60)

print('mean_absolute_error:',mae)
print("*"*60)

print('r2_score:',r2)
testing_accuracy_list.append(r2)
# Out:
# mean_squared_error: 2042.7810430037719
# ************************************************************
# rmse: 45.1971353406803
# ************************************************************
# mean_absolute_error: 40.66646971092551
# ************************************************************
# r2_score: 0.7804407061652039

# %% [markdown]
# #Lasso Regression

# %%
lasso_reg=Lasso(alpha=0.001)
lasso_reg.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.001)

# %%
#Training
y_train_pred=lasso_reg.predict(x_train)
mse=mean_squared_error(y_train_pred,y_train)
rmse=np.sqrt(mse)
mae=mean_absolute_error(y_train_pred,y_train)

r2=r2_score(y_train_pred,y_train)

print('mean_squared_error:',mse)
print("*"*60)

print('rmse:',rmse)
print("*"*60)

print('mean_absolute_error:',mae)
print("*"*60)

print('r2_score:',r2)
training_accuracy_list.append(r2)
# Out:
# mean_squared_error: 1615.8315425226908
# ************************************************************
# rmse: 40.19740716169005
# ************************************************************
# mean_absolute_error: 33.723937204988864
# ************************************************************
# r2_score: 0.8132565743234766

# %%
#Testing
y_test_pred=lasso_reg.predict(x_test)
mse=mean_squared_error(y_test_pred,y_test)
rmse=np.sqrt(mse)
mae=mean_absolute_error(y_test_pred,y_test)

r2=r2_score(y_test_pred,y_test)

print('mean_squared_error:',mse)
print("*"*60)

print('rmse:',rmse)
print("*"*60)

print('mean_absolute_error:',mae)
print("*"*60)

print('r2_score:',r2)
testing_accuracy_list.append(r2)
# Out:
# mean_squared_error: 2042.6472172990254
# ************************************************************
# rmse: 45.195654849764324
# ************************************************************
# mean_absolute_error: 40.665688616816766
# ************************************************************
# r2_score: 0.7804522526596318

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %% [markdown]
# 📈Implementing Cross Validation Of Ridge
# Cross-Validation is a resampling technique with the fundamental idea of splitting the dataset into 2 parts- training data and test data. Train data is used to train the model and the unseen test data is used for prediction. If the model performs well over the test data and gives good accuracy, it means the model hasn’t overfitted the training data and can be used for prediction.
#
# To overcome over-fitting problems, we use a technique called Cross-Validation.
# Let’s dive deep and learn about some of the model evaluation techniques.

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %%
# Fit the Algorithm

ridg_reg=Ridge()
parameter_grid=({"alpha":np.arange(0.01,3,0.01)})
gscv_ridge=GridSearchCV(ridg_reg,parameter_grid,cv=5)
gscv_ridge.fit(x_train,y_train)
gscv_ridge.best_estimator_
# Out:
# Ridge(alpha=2.9899999999999998)

# %%
# Fit the Algorithm

lasso_reg=Lasso()
parameter_grid=({"alpha":np.arange(0.01,3,0.01)})
gscv_lasso=GridSearchCV(lasso_reg,parameter_grid,cv=5)
gscv_lasso.fit(x_train,y_train)
gscv_lasso.best_estimator_
# Out:
# Lasso(alpha=2.9899999999999998)

# %%
# Predict on the model
#Training After Hyperparameter Tunning ridge
y_train_pred=gscv_ridge.predict(x_train)
mse=mean_squared_error(y_train_pred,y_train)
rmse=np.sqrt(mse)
mae=mean_absolute_error(y_train_pred,y_train)

r2=r2_score(y_train_pred,y_train)

print('mean_squared_error:',mse)
print("*"*60)

print('rmse:',rmse)
print("*"*60)

print('mean_absolute_error:',mae)
print("*"*60)

print('r2_score:',r2)
training_accuracy_list.append(r2)
# Out:
# mean_squared_error: 1688.5739051034222
# ************************************************************
# rmse: 41.09226089062784
# ************************************************************
# mean_absolute_error: 34.53726908748815
# ************************************************************
# r2_score: 0.7992554371198364

# %%
#Testing  After Hyperparameter Tunning ridge

y_test_pred=gscv_ridge.predict(x_test)
mse=mean_squared_error(y_test_pred,y_test)
rmse=np.sqrt(mse)
mae=mean_absolute_error(y_test_pred,y_test)

r2=r2_score(y_test_pred,y_test)

print('mean_squared_error:',mse)
print("*"*60)

print('rmse:',rmse)
print("*"*60)

print('mean_absolute_error:',mae)
print("*"*60)

print('r2_score:',r2)
testing_accuracy_list.append(r2)
# Out:
# mean_squared_error: 1991.829273327426
# ************************************************************
# rmse: 44.6299145565777
# ************************************************************
# mean_absolute_error: 39.64828490074457
# ************************************************************
# r2_score: 0.7826633017007592

# %%
#Training After Hyperparameter Tunning Lasso

y_train_pred=gscv_lasso.predict(x_train)
mse=mean_squared_error(y_train_pred,y_train)
rmse=np.sqrt(mse)
mae=mean_absolute_error(y_train_pred,y_train)

r2=r2_score(y_train_pred,y_train)

print('mean_squared_error:',mse)
print("*"*60)

print('rmse:',rmse)
print("*"*60)

print('mean_absolute_error:',mae)
print("*"*60)

print('r2_score:',r2)
training_accuracy_list.append(r2)
# Out:
# mean_squared_error: 1685.1329648117628
# ************************************************************
# rmse: 41.050371067893686
# ************************************************************
# mean_absolute_error: 34.35392635879583
# ************************************************************
# r2_score: 0.7899603087195557

# %%
#Testing  After Hyperparameter Tunning Lassso

y_test_pred=gscv_lasso.predict(x_test)
mse=mean_squared_error(y_test_pred,y_test)
rmse=np.sqrt(mse)
mae=mean_absolute_error(y_test_pred,y_test)

r2=r2_score(y_test_pred,y_test)

print('mean_squared_error:',mse)
print("*"*60)

print('rmse:',rmse)
print("*"*60)

print('mean_absolute_error:',mae)
print("*"*60)

print('r2_score:',r2)
testing_accuracy_list.append(r2)
# Out:
# mean_squared_error: 1888.1016228356614
# ************************************************************
# rmse: 43.452291341604315
# ************************************************************
# mean_absolute_error: 38.57211435261053
# ************************************************************
# r2_score: 0.783433572746701

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Here we use GridSerchcv as hyperparamater tunning techinque beacause it gives more accuracy than RandomizedSearchcv.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# By using hyperparameter tunning we reduced the overfitting of model.

# %% [markdown]
# ### ML Model - 2
# #Decision Tree

# %%
# ML Model - 2 Implementation
dt_reg=DecisionTreeRegressor(random_state=11)

# Fit the Algorithm
dt_reg.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=11)

# %%
# Predict on the model
y_train_pred=dt_reg.predict(x_train)

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart
#Training Decision tree regression
y_train_pred=dt_reg.predict(x_train)
mse=mean_squared_error(y_train_pred,y_train)
rmse=np.sqrt(mse)
mae=mean_absolute_error(y_train_pred,y_train)

r2=r2_score(y_train_pred,y_train)

print('mean_squared_error:',mse)
print("*"*60)

print('rmse:',rmse)
print("*"*60)

print('mean_absolute_error:',mae)
print("*"*60)

print('r2_score:',r2)
training_accuracy_list.append(r2)
# Out:
# mean_squared_error: 0.0
# ************************************************************
# rmse: 0.0
# ************************************************************
# mean_absolute_error: 0.0
# ************************************************************
# r2_score: 1.0

# %%
#Testing Decision tree regression

y_test_pred=dt_reg.predict(x_test)
mse=mean_squared_error(y_test_pred,y_test)
rmse=np.sqrt(mse)
mae=mean_absolute_error(y_test_pred,y_test)

r2=r2_score(y_test_pred,y_test)

print('mean_squared_error:',mse)
print("*"*60)

print('rmse:',rmse)
print("*"*60)

print('mean_absolute_error:',mae)
print("*"*60)

print('r2_score:',r2)
testing_accuracy_list.append(r2)
# Out:
# mean_squared_error: 98.19889787234034
# ************************************************************
# rmse: 9.90953570417607
# ************************************************************
# mean_absolute_error: 6.074468085106382
# ************************************************************
# r2_score: 0.9863684171307262

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %%
dt_reg=DecisionTreeRegressor(random_state=12)

parameter_grid=({'criterion':["squared_error",'absolute_error'],
                'max_depth':np.arange(3,8),
               'min_samples_split':np.arange(3,15),
                'max_leaf_nodes':np.arange(3,20)})
gsec_dt_reg=GridSearchCV(dt_reg,parameter_grid,cv=5)
gsec_dt_reg.fit(x_train,y_train)
gsec_dt_reg.best_estimator_
# Out:
# DecisionTreeRegressor(criterion='absolute_error', max_depth=6,
#                       max_leaf_nodes=18, min_samples_split=3, random_state=12)

# %%
#Training After Hyperparameter Decision tree regression
y_train_pred=gsec_dt_reg.predict(x_train)
mse=mean_squared_error(y_train_pred,y_train)
rmse=np.sqrt(mse)
mae=mean_absolute_error(y_train_pred,y_train)

r2=r2_score(y_train_pred,y_train)

print('mean_squared_error:',mse)
print("*"*60)

print('rmse:',rmse)
print("*"*60)

print('mean_absolute_error:',mae)
print("*"*60)

print('r2_score:',r2)
training_accuracy_list.append(r2)
# Out:
# mean_squared_error: 43.35902789855073
# ************************************************************
# rmse: 6.5847572391509415
# ************************************************************
# mean_absolute_error: 4.160507246376811
# ************************************************************
# r2_score: 0.9958810891093084

# %%
#Testing After Hyperparametr Decision tree regression

y_test_pred=gsec_dt_reg.predict(x_test)
mse=mean_squared_error(y_test_pred,y_test)
rmse=np.sqrt(mse)
mae=mean_absolute_error(y_test_pred,y_test)

r2=r2_score(y_test_pred,y_test)

print('mean_squared_error:',mse)
print("*"*60)

print('rmse:',rmse)
print("*"*60)

print('mean_absolute_error:',mae)
print("*"*60)

print('r2_score:',r2)
testing_accuracy_list.append(r2)
# Out:
# mean_squared_error: 106.94329148936161
# ************************************************************
# rmse: 10.3413389601812
# ************************************************************
# mean_absolute_error: 6.810638297872337
# ************************************************************
# r2_score: 0.9857771253606844

# %%
result=dt_reg.cost_complexity_pruning_path(x_train,y_train)
ccp_alpha_list=result['ccp_alphas']
ccp_alpha_list
# Out:
# array([0.00000000e+00, 1.44927536e-06, 5.79710145e-06, 9.05797081e-06,
#        1.30434780e-05, 1.30434783e-05, 1.77536232e-05, 2.93478262e-05,
#        4.38405797e-05, 8.16425121e-05, 9.27536232e-05, 1.04710145e-04,
#        1.30797101e-04, 1.44927536e-04, 2.03019324e-04, 2.84057971e-04,
#        2.84057971e-04, 3.26086957e-04, 3.48188406e-04, 3.71014493e-04,
#        4.78321256e-04, 5.23188406e-04, 5.79710145e-04, 6.39130435e-04,
#        7.16062802e-04, 8.52173913e-04, 8.69927536e-04, 1.30887681e-03,
#        2.14818841e-03, 2.14818841e-03, 3.06666667e-03, 3.74106280e-03,
#        3.99456522e-03, 4.14818841e-03, 4.22608696e-03, 4.54492754e-03,
#        4.79166667e-03, 4.87536232e-03, 5.76576087e-03, 6.33345411e-03,
#        8.03913043e-03, 8.95078502e-03, 9.98405797e-03, 1.03945894e-02,
#        1.04710145e-02, 1.05816425e-02, 1.13827295e-02, 1.16812802e-02,
#        1.18699275e-02, 1.30797101e-02, 1.62840580e-02, 1.80081522e-02,
# ...

# %%
train_accuracy_list = []
test_accuracy_list = []

for i in ccp_alpha_list:
    decision_tree_model = DecisionTreeRegressor(ccp_alpha=i, random_state=11)
    decision_tree_model.fit(x_train, y_train)

    training_accuracy = decision_tree_model.score(x_train, y_train)
    train_accuracy_list.append(training_accuracy)

    testing_accuracy = decision_tree_model.score(x_test, y_test)
    test_accuracy_list.append(testing_accuracy)
pd.DataFrame(train_accuracy_list)
# Out:
#             0
# 0    1.000000
# 1    1.000000
# 2    1.000000
# 3    1.000000
# 4    1.000000
# ..        ...
# 131  0.961652
# 132  0.944106
# 133  0.944106
# 134  0.900393
# 135  0.000000
#
# [136 rows x 1 columns]

# %%
fig, ax = plt.subplots()
ax.plot(ccp_alpha_list, train_accuracy_list, label = "Training Data Accuracy")
ax.plot(ccp_alpha_list, test_accuracy_list, label = "Testing Data Accuracy")
ax.legend()

# %%
max_test = test_accuracy_list.index(max(test_accuracy_list))
max_test
# Out:
# 29

# %%
best_ccp = ccp_alpha_list[max_test]
best_ccp
# Out:
# 0.0021481884057991106

# %%
decision_tree_model = DecisionTreeRegressor(ccp_alpha= best_ccp,random_state=11)

decision_tree_model.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0021481884057991106, random_state=11)

# %%
#Training
y_train_pred=decision_tree_model.predict(x_train)
mse=mean_squared_error(y_train_pred,y_train)
rmse=np.sqrt(mse)
mae=mean_absolute_error(y_train_pred,y_train)

r2=r2_score(y_train_pred,y_train)
print("*"*60)

print('mean_squared_error:',mse)
print("*"*60)

print('rmse:',rmse)
print("*"*60)

print('mean_absolute_error:',mae)
print("*"*60)

print('r2_score:',r2)
training_accuracy_list.append(r2)
# Out:
# ************************************************************
# mean_squared_error: 0.012768357487922762
# ************************************************************
# rmse: 0.11299715699044274
# ************************************************************
# mean_absolute_error: 0.056352657004831205
# ************************************************************
# r2_score: 0.9999987566189394

# %%
#Testing
y_test_pred=decision_tree_model.predict(x_test)
mse=mean_squared_error(y_test_pred,y_test)
rmse=np.sqrt(mse)
mae=mean_absolute_error(y_test_pred,y_test)

r2=r2_score(y_test_pred,y_test)
print("*"*60)

print('mean_squared_error:',mse)
print("*"*60)

print('rmse:',rmse)
print("*"*60)

print('mean_absolute_error:',mae)
print("*"*60)

print('r2_score:',r2)
testing_accuracy_list.append(r2)
# Out:
# ************************************************************
# mean_squared_error: 97.90438911052001
# ************************************************************
# rmse: 9.894664679033848
# ************************************************************
# mean_absolute_error: 6.068386524822692
# ************************************************************
# r2_score: 0.986410829113254

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Here we use GridSerchcv as hyperparamater tunning techinque beacause it gives more accuracy than RandomizedSearchcv.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# By using hyperparameter tunning we reduced the overfitting of model.As training accuracy reduces and testing accuracy increses and reduce the error between them.

# %% [markdown]
# ### ML Model - 3
# #RandomForest

# %%
# ML Model - 3 Implementation
rf_tree_reg=RandomForestRegressor(random_state=12)

# Fit the Algorithm
rf_tree_reg.fit(x_train,y_train)
# Out:
# RandomForestRegressor(random_state=12)

# %%
# Predict on the model
y_train_pred=rf_tree_reg.predict(x_train)

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart
#Training
y_train_pred=rf_tree_reg.predict(x_train)
mse=mean_squared_error(y_train_pred,y_train)
rmse=np.sqrt(mse)
mae=mean_absolute_error(y_train_pred,y_train)

r2=r2_score(y_train_pred,y_train)
print("*"*60)

print('mean_squared_error:',mse)
print("*"*60)

print('rmse:',rmse)
print("*"*60)

print('mean_absolute_error:',mae)
print("*"*60)

print('r2_score:',r2)
training_accuracy_list.append(r2)
# Out:
# ************************************************************
# mean_squared_error: 25.277170829347984
# ************************************************************
# rmse: 5.027640682203531
# ************************************************************
# mean_absolute_error: 2.5926471014492796
# ************************************************************
# r2_score: 0.9975315612751379

# %%
#Testing
y_test_pred=rf_tree_reg.predict(x_test)
mse=mean_squared_error(y_test_pred,y_test)
rmse=np.sqrt(mse)
mae=mean_absolute_error(y_test_pred,y_test)

r2=r2_score(y_test_pred,y_test)
print("*"*60)

print('mean_squared_error:',mse)
print("*"*60)

print('rmse:',rmse)
print("*"*60)

print('mean_absolute_error:',mae)
print("*"*60)

print('r2_score:',r2)
testing_accuracy_list.append(r2)
# Out:
# ************************************************************
# mean_squared_error: 115.45895237595745
# ************************************************************
# rmse: 10.74518275209675
# ************************************************************
# mean_absolute_error: 6.237661702127649
# ************************************************************
# r2_score: 0.9844052717600983

# %% [markdown]
# ### ML Model - 4
# #KNeighbors Regression

# %%
# ML Model - 4 Implementation

knn_reg=KNeighborsRegressor()

# Fit the Algorithm
knn_reg.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
# Predict on the model
y_train_pred=knn_reg.predict(x_train)

# %%
#Training
mse=mean_squared_error(y_train_pred,y_train)
rmse=np.sqrt(mse)
mae=mean_absolute_error(y_train_pred,y_train)

r2=r2_score(y_train_pred,y_train)
print("*"*60)

print('mean_squared_error:',mse)
print("*"*60)

print('rmse:',rmse)
print("*"*60)

print('mean_absolute_error:',mae)
print("*"*60)

print('r2_score:',r2)
training_accuracy_list.append(r2)
# Out:
# ************************************************************
# mean_squared_error: 88.53411892753623
# ************************************************************
# rmse: 9.409257086908415
# ************************************************************
# mean_absolute_error: 5.57891304347826
# ************************************************************
# r2_score: 0.9913657867271729

# %%
#Testing
y_test_pred=knn_reg.predict(x_test)
mse=mean_squared_error(y_test_pred,y_test)
rmse=np.sqrt(mse)
mae=mean_absolute_error(y_test_pred,y_test)

r2=r2_score(y_test_pred,y_test)
print("*"*60)

print('mean_squared_error:',mse)
print("*"*60)

print('rmse:',rmse)
print("*"*60)

print('mean_absolute_error:',mae)
print("*"*60)

print('r2_score:',r2)
testing_accuracy_list.append(r2)
# Out:
# ************************************************************
# mean_squared_error: 188.2234822978723
# ************************************************************
# rmse: 13.719456341191961
# ************************************************************
# mean_absolute_error: 7.229148936170211
# ************************************************************
# r2_score: 0.9750747913349097

# %% [markdown]
# #Normalization

# %%
normal_scalar=MinMaxScaler()
array=normal_scalar.fit_transform(x_train)
x_train_normal_df=pd.DataFrame(array,columns=x_train.columns)
knn_reg=KNeighborsRegressor(n_neighbors=7,p=1)
knn_reg.fit(x_train_normal_df,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=7, p=1)

# %%
#Training
y_train_pred=knn_reg.predict(x_train_normal_df)
mse=mean_squared_error(y_train_pred,y_train)
rmse=np.sqrt(mse)
mae=mean_absolute_error(y_train_pred,y_train)

r2=r2_score(y_train_pred,y_train)
print("*"*60)

print('mean_squared_error:',mse)
print("*"*60)

print('rmse:',rmse)
print("*"*60)

print('mean_absolute_error:',mae)
print("*"*60)

print('r2_score:',r2)
training_accuracy_list.append(r2)
# Out:
# ************************************************************
# mean_squared_error: 182.51370224785575
# ************************************************************
# rmse: 13.509763219533337
# ************************************************************
# mean_absolute_error: 6.933788819875775
# ************************************************************
# r2_score: 0.9823139071875612

# %%
#Testing
array=normal_scalar.transform(x_test)
x_test_normal_df=pd.DataFrame(array,columns=x_test.columns)
y_test_pred=knn_reg.predict(x_test_normal_df)
mse=mean_squared_error(y_test_pred,y_test)
rmse=np.sqrt(mse)
mae=mean_absolute_error(y_test_pred,y_test)

r2=r2_score(y_test_pred,y_test)
print("*"*60)

print('mean_squared_error:',mse)
print("*"*60)

print('rmse:',rmse)
print("*"*60)

print('mean_absolute_error:',mae)
print("*"*60)

print('r2_score:',r2)
testing_accuracy_list.append(r2)
# Out:
# ************************************************************
# mean_squared_error: 267.35832878853665
# ************************************************************
# rmse: 16.35109564489599
# ************************************************************
# mean_absolute_error: 7.782917933130696
# ************************************************************
# r2_score: 0.9657176121692631

# %% [markdown]
# #Standardization

# %%
#create an instance
std_scalar=StandardScaler()
array=std_scalar.fit_transform(x_train)
x_train_std_df=pd.DataFrame(array, columns=x_train.columns)
knn_reg=KNeighborsRegressor(n_neighbors=7,p=1)
knn_reg.fit(x_train_std_df,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=7, p=1)

# %%
#Training
y_train_pred=knn_reg.predict(x_train_std_df)
mse=mean_squared_error(y_train_pred,y_train)
rmse=np.sqrt(mse)
mae=mean_absolute_error(y_train_pred,y_train)

r2=r2_score(y_train_pred,y_train)
print("*"*60)

print('mean_squared_error:',mse)
print("*"*60)

print('rmse:',rmse)
print("*"*60)

print('mean_absolute_error:',mae)
print("*"*60)

print('r2_score:',r2)
training_accuracy_list.append(r2)
# Out:
# ************************************************************
# mean_squared_error: 181.14716870748305
# ************************************************************
# rmse: 13.45909241767375
# ************************************************************
# mean_absolute_error: 6.89167701863354
# ************************************************************
# r2_score: 0.9824446305250858

# %%
array=std_scalar.transform(x_test)
x_test_std_df=pd.DataFrame(array, columns=x_test.columns)
y_test_pred=knn_reg.predict(x_test_std_df)
mse=mean_squared_error(y_test_pred,y_test)
rmse=np.sqrt(mse)
mae=mean_absolute_error(y_test_pred,y_test)

r2=r2_score(y_test_pred,y_test)
print("*"*60)

print('mean_squared_error:',mse)
print("*"*60)

print('rmse:',rmse)
print("*"*60)

print('mean_absolute_error:',mae)
print("*"*60)

print('r2_score:',r2)
testing_accuracy_list.append(r2)
# Out:
# ************************************************************
# mean_squared_error: 262.3896303517151
# ************************************************************
# rmse: 16.1984453066248
# ************************************************************
# mean_absolute_error: 7.699544072948327
# ************************************************************
# r2_score: 0.9664347993519151

# %% [markdown]
# ### ML Model - 5

# %% [markdown]
# #Adaboost

# %%
# ML Model - 5 Implementation
#create instance
adb_reg=AdaBoostRegressor(random_state=12)


# Fit the Algorithm
adb_reg.fit(x_train,y_train)
# Out:
# AdaBoostRegressor(random_state=12)

# %%
# Predict on the model
y_train_pred=adb_reg.predict(x_train)

# %%
#Training

mse=mean_squared_error(y_train_pred,y_train)
rmse=np.sqrt(mse)
mae=mean_absolute_error(y_train_pred,y_train)

r2=r2_score(y_train_pred,y_train)
print("*"*60)

print('mean_squared_error:',mse)
print("*"*60)

print('rmse:',rmse)
print("*"*60)

print('mean_absolute_error:',mae)
print("*"*60)

print('r2_score:',r2)
training_accuracy_list.append(r2)
# Out:
# ************************************************************
# mean_squared_error: 48.421357877699
# ************************************************************
# rmse: 6.9585456726027894
# ************************************************************
# mean_absolute_error: 5.731073366905846
# ************************************************************
# r2_score: 0.9951943841304757

# %%
#Testing
y_test_pred=adb_reg.predict(x_test)
mse=mean_squared_error(y_test_pred,y_test)
rmse=np.sqrt(mse)
mae=mean_absolute_error(y_test_pred,y_test)

r2=r2_score(y_test_pred,y_test)
print("*"*60)

print('mean_squared_error:',mse)
print("*"*60)

print('rmse:',rmse)
print("*"*60)

print('mean_absolute_error:',mae)
print("*"*60)

print('r2_score:',r2)
testing_accuracy_list.append(r2)
# Out:
# ************************************************************
# mean_squared_error: 119.85421681221696
# ************************************************************
# rmse: 10.947795066232148
# ************************************************************
# mean_absolute_error: 8.411793094934783
# ************************************************************
# r2_score: 0.9831168270492489

# %% [markdown]
# ### ML Model - 6

# %%
# fitting the data into XGBoost Regressor
from xgboost import XGBRegressor

xgb_reg = XGBRegressor()
xgb_reg.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
#Training
y_train_pred=xgb_reg.predict(x_train)
mse=mean_squared_error(y_train_pred,y_train)
rmse=np.sqrt(mse)
mae=mean_absolute_error(y_train_pred,y_train)

r2=r2_score(y_train_pred,y_train)
print("*"*60)

print('mean_squared_error:',mse)
print("*"*60)

print('rmse:',rmse)
print("*"*60)

print('mean_absolute_error:',mae)
print("*"*60)

print('r2_score:',r2)
training_accuracy_list.append(r2)
# Out:
# ************************************************************
# mean_squared_error: 0.0006511611431720292
# ************************************************************
# rmse: 0.025517859298382167
# ************************************************************
# mean_absolute_error: 0.01816009466198889
# ************************************************************
# r2_score: 0.9999999365887243

# %%
#Testing
y_test_pred=xgb_reg.predict(x_test)
mse=mean_squared_error(y_test_pred,y_test)
rmse=np.sqrt(mse)
mae=mean_absolute_error(y_test_pred,y_test)

r2=r2_score(y_test_pred,y_test)
print("*"*60)

print('mean_squared_error:',mse)
print("*"*60)

print('rmse:',rmse)
print("*"*60)

print('mean_absolute_error:',mae)
print("*"*60)

print('r2_score:',r2)
testing_accuracy_list.append(r2)
# Out:
# ************************************************************
# mean_squared_error: 111.50328728662
# ************************************************************
# rmse: 10.559511697357033
# ************************************************************
# mean_absolute_error: 7.163555515370466
# ************************************************************
# r2_score: 0.9845089953941318

# %%
model_details = ['LinearRegression','Ridge','Lasso','Ridgr_hyper','Lasso_hyper','DecisionTree','DecisionTree_Hyper_pre','DecisionTree_Hyper_post',
                 'RandomForest','KNN',"KNN_Normalization",'KNN_standerdization','AdaBoost',"xgboost"]

# %%
len(training_accuracy_list)
# Out:
# 14

# %%
training_accuracy=pd.DataFrame(training_accuracy_list,columns=['training_accuracy_list'])
testing_accuracy=pd.DataFrame(testing_accuracy_list,columns=['testing_accuracy_list'])
model_details=pd.DataFrame(model_details,columns=['model_details'])

final_accuracy=pd.concat([model_details,training_accuracy,testing_accuracy],axis=1)
final_accuracy
# Out:
#               model_details  training_accuracy_list  testing_accuracy_list
# 0          LinearRegression                0.813269               0.780418
# 1                     Ridge                0.813260               0.780441
# 2                     Lasso                0.813257               0.780452
# 3               Ridgr_hyper                0.799255               0.782663
# 4               Lasso_hyper                0.789960               0.783434
# 5              DecisionTree                1.000000               0.986368
# 6    DecisionTree_Hyper_pre                0.995881               0.985777
# 7   DecisionTree_Hyper_post                0.999999               0.986411
# 8              RandomForest                0.997532               0.984405
# 9                       KNN                0.991366               0.975075
# 10        KNN_Normalization                0.982314               0.965718
# ...

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# 	DecisionTree is giving good accuracy as compared to all other models,it gives training as well as testing accuracy good .

# %% [markdown]
# ## ***8.*** ***Future Work (Optional)***

# %% [markdown]
# ### 1. Save the best performing ml model in a pickle file or joblib file format for deployment process.

# %%
# Save the File

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# - We started with data inspection, viewed the data distribution, checked for correlation and used averaged features to remove correlation.
#
# - A simple linear regression model was built and it was evaluated using accuracy, mean squared error, root mean squared error, r2_score and mean absolute percentage error.
#
# - Additional features were engineered by taking lags and reduced the effect of multi collinearity using regularization techniques such as ridge and lasso
#
# - Regression models namely DecisioinTreeRrgressor, RandomForestRegressor, KNN Regressor, XGboostRegressor, AdaboostRegressor  were built.
#
# - High, low, open are directly correlate with the closing price of stocks
#
# - Target variable(dependent variable) strongly dependent on independent variables

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
